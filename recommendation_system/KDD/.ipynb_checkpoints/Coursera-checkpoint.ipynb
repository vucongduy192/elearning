# %%
import pandas as pd
import string

# %% [markdown]
# ## Course detail

# %%
def isEnglish(row):
    try:
        row['Name'].encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True
    
def hasRating(row):
    if row['Rating'] == "None":
        return False
    return True

def hasLevel(row):
    if row['Difficulty'] == "None":
        return False
    return True

# %%
# Total records
df = pd.read_csv('coursera-course-detail-data.csv', 
                 converters={'Tags': lambda x: x[1:-1].replace("'", "").split(',')})
len(df)
# Out:
# 3850

# %%
type(df.Rating[0])
# Out:
# str

# %%
english_name = df.apply(isEnglish, axis=1)
df = df[english_name]
len(df)
# Out:
# 2942

# %%
has_rating = df.apply(hasRating, axis=1)
df = df[has_rating]
len(df)
# Out:
# 2668

# %%
hasLevel = df.apply(hasLevel, axis=1)
df = df[hasLevel]
len(df)
# Out:
# 1763

# %%
df[:50]
# Out:
#      Unnamed: 0                                               Name  \
# 8             8          3-Axis Machining with Autodesk Fusion 360
# 10           10                          3D Art and Audio Pipeline
# 11           11                                 3D CAD Application
# 12           12                                 3D CAD Fundamental
# 16           16                          Brand & Content Marketing
# 18           18  FPGA computing systems: Background knowledge a...
# 19           19                   Future Healthcare Payment Models
# 21           21              Geospatial and Environmental Analysis
# 22           22                      Combinatorics and Probability
# 33           33  Spanish for Successful Communication in Health...
# 34           34    Digital Product Management: Modern Fundamentals
# 35           35          Digital Competition in Financial Services
# 36           36              Mathematics for Machine Learning: PCA
# 37           37  Programming Foundations with JavaScript, HTML ...
# 39           39        Probabilistic Graphical Models 2: Inference
# 40           40                          Evidence-based Toxicology
# 41           41  Identifying Social Entrepreneurship Opportunities
# 42           42                    Launching into Machine Learning
# 44           44                              Quantitative Research
# 45           45        Sprachtechnologie in den Digital Humanities
# 46           46                 Learn to Program: The Fundamentals
# 53           53     Strategic Business Management - Macroeconomics
# 54           54                                   Data in Database
# 56           56     Competencias digitales. Bases de datos: Access
# 58           58  Climate Change and Water in Mountains: A Globa...
# 60           60  Tropical Parasitology: Protozoans, Worms, Vect...
# 61           61                 Managerial Accounting Fundamentals
# 62           62                  The Strategy of Content Marketing
# 64           64             The Science of Training Young Athletes
# 67           67  Building Resilient Streaming Analytics Systems...
# 68           68           Introduction to Applied Machine Learning
# 69           69          Introduction to Climate Change and Health
# 73           73                             Analytic Combinatorics
# 74           74                 Supply chain management: Be global
# 81           81  The Modern World, Part One: Global History fro...
# 85           85                   Introduction to Complex Analysis
# 86           86               Organizational Design and Management
# 88           88                    Global Environmental Management
# 92           92                      Introduction to Deep Learning
# 99           99                    Construction Project Management
# 101         101                               Logic for Economists
# 107         107             Intelligence Tools for the Digital Age
# 108         108                   Tinkering Fundamentals: Circuits
# 109         109                    Marketing Internacional en Asia
# 111         111      Designing, Running, and Analyzing Experiments
# 113         113     Valuation for Startups Using Multiple Approach
# 117         117  Global Postharvest Loss Prevention: Fundamenta...
# 118         118                               Blockchain Platforms
# 122         122  Creating New BigQuery Datasets and Visualizing...
# 123         123  Mindware: Critical Thinking for the Informatio...
#
#                                                    Url Rating  \
# 8    https://coursera.org/learn/3-axis-machining-au...      5
# 10   https://coursera.org/learn/3d-art-and-audio-pi...    4.3
# 33   Intermediate Level                            [Health,  Patient Care]
# 34       Beginner Level             [Business,  Leadership and Management]
# 35       Beginner Level                     [Business,  Business Strategy]
# 36   Intermediate Level                  [Data Science,  Machine Learning]
# 37       Beginner Level    [Computer Science,  Mobile and Web Development]
# 39       Advanced Level                  [Data Science,  Machine Learning]
# 40       Beginner Level                           [Health,  Basic Science]
# 41       Beginner Level                      [Business,  Entrepreneurship]
# 42   Intermediate Level                  [Data Science,  Machine Learning]
# 44   Intermediate Level                             [Business,  Marketing]
# 45       Beginner Level                     [Data Science,  Data Analysis]
# 46       Beginner Level          [Computer Science,  Software Development]
# 53       Beginner Level                     [Business,  Business Strategy]
# 54   Intermediate Level         [Information Technology,  Data Management]
# 56       Beginner Level      [Personal Development,  Personal Development]
# 58   Intermediate Level  [Physical Science and Engineering,  Environmen...
# 60   Intermediate Level                           [Health,  Basic Science]
# 61       Beginner Level                               [Business,  Finance]
# 62   Intermediate Level                             [Business,  Marketing]
# 64       Beginner Level      [Personal Development,  Personal Development]
# 67   Intermediate Level         [Information Technology,  Cloud Computing]
# 68   Intermediate Level                  [Data Science,  Machine Learning]
# 69       Beginner Level                           [Health,  Public Health]
# 73   Intermediate Level                  [Math and Logic,  Math and Logic]
# 74       Beginner Level                     [Business,  Business Strategy]
# 81       Beginner Level                    [Arts and Humanities,  History]
# 85   Intermediate Level                  [Math and Logic,  Math and Logic]
# 86       Beginner Level                     [Business,  Business Strategy]
# 88   Intermediate Level  [Physical Science and Engineering,  Environmen...
# 92       Advanced Level                  [Data Science,  Machine Learning]
# 99       Beginner Level                     [Business,  Business Strategy]
# 101      Advanced Level                  [Math and Logic,  Math and Logic]
# 107      Beginner Level             [Business,  Leadership and Management]
# 108      Beginner Level      [Personal Development,  Personal Development]
# 109      Beginner Level                             [Business,  Marketing]
# 111  Intermediate Level            [Computer Science,  Design and Product]
# 113      Beginner Level                               [Business,  Finance]
# 117      Beginner Level  [Physical Science and Engineering,  Environmen...
# 118  Intermediate Level          [Computer Science,  Software Development]
# 122      Beginner Level         [Information Technology,  Data Management]
# 123      Beginner Level                              [Health,  Psychology]

# %%
categories = df.Tags.explode().value_counts()[:-1]

# %%
type(categories)
# Out:
# pandas.core.series.Series

# %%
len(categories.index)
# Out:
# 55

# %%
categories.index[0]
# Out:
# 'Business'

# %%
for idx, count in enumerate(categories):
    if categories.index[idx][0] != " ":
        print(categories.index[idx], count)
# Out:
# Business 371
# Computer Science 279
# Health 239
# Physical Science and Engineering 182
# Data Science 177
# Arts and Humanities 143
# Social Sciences 134
# Information Technology 99
# Language Learning 61
# Personal Development 57
# Math and Logic 21

# %% [markdown]
# ## Course rating

# %%
# Total records
rating_df = pd.read_csv('reviews_by_course.csv')
len(df)
# Out:
# 1763

# %%
rating_df.head()
# Out:
#      CourseId                                             Review  Label
# 0  2-speed-it                                             BOring      1
# 1  2-speed-it                                            Bravo !      5
# 2  2-speed-it                                           Very goo      5
# 3  2-speed-it  Great course - I recommend it for all, especia...      5
# 4  2-speed-it    One of the most useful course on IT Management!      5

# %%
rating_df
